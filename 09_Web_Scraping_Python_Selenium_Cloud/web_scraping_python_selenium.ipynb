# %% [markdown]
# # Web Scraping with Python and Selenium

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import re
import json
import time
import random
import pandas as pd

from bs4 import BeautifulSoup

from prettytable import from_csv

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support import expected_conditions as EC

# Set up Chrome options
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# Path to ChromeDriver
service = Service('/usr/local/bin/chromedriver')

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: /workspaces/data_ingestion/09_Web_Scraping_Python_Selenium_Cloud

# %% [markdown]
# ## Import a list with user agents

# %%
# Liste mit User-Agents für Rotation
ua_path = "user_agents.txt"
ua_list = [line.rstrip('\n') for line in open(ua_path)]
ua_list[:5]
# Out:
# ['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0.4 Safari/605.1.15']

# %% [markdown]
# ## Chrome headless mode (without graphical user interface)

# %%
# Initialize the driver
driver = webdriver.Chrome(service=service, options=options)

# Website to scrape
driver.get('https://store.dji.com')

# Get current url
print(driver.current_url)

# Return the full page HTML code
# print(driver.page_source)

# Gets the page's title
print(driver.title)

# Close driver
driver.close()
# Out:
# https://store.dji.com/nl
# DJI Store - Official Store for DJI Drones, Gimbals and Accessories (Netherlands)

# %% [markdown]
# ## Creating screenshots from a website

# %%
# Chrome-Driver
driver = webdriver.Chrome(service=service, options=options)

# Website to scrape
driver.get('https://store.dji.com')

# Screenshot
driver.save_screenshot('screenshot.png')

# Plot image
img = mpimg.imread('screenshot.png')
plt.figure(figsize=(8,8))
plt.axis('off')
imgplot = plt.imshow(img)

# Close driver
driver.close()

# %% [markdown]
# ## Locating elements
#
# There are different methods available in the Selenium API to select elements on the page. You can use:
#
# - Name
# - Tag name
# - Class name
# - ID
# - XPath
# - CSS selectors
#
# Use the inspect element function in Chrome to get these infos:
# https://www.hostinger.com/tutorials/website/how-to-inspect-and-change-style-using-google-chrome

# %% [markdown]
# ### Locating elements using XPath

# %%
# Chrome-Driver
driver = webdriver.Chrome(service=service, options=options)

# Website to scrape
driver.get('https://de.wikipedia.org/wiki/Hot_Rod')

# Screenshot
driver.save_screenshot('screenshot.png')

# Plot image
img = mpimg.imread('screenshot.png')
plt.figure(figsize=(8,8))
plt.axis('off')
imgplot = plt.imshow(img)

# Find element using xpath
text = driver.find_element(By.XPATH, '/html/body/div[2]/div/div[3]/main/div[3]/div[3]/div[2]/figure[1]/figcaption').text
print(text)

# Close driver
driver.close()
# Out:
# Ein Deuce von 1932, der mittels Chopping und Cleaning modifiziert wurde

# %% [markdown]
# ### Locating elements using tag names

# %%
# Chrome-Driver
driver = webdriver.Chrome(service=service, options=options)

# Website to scrape
driver.get('https://www.tagesschau.de/wissen/klima/bienen-impfung-faulbrut-107.html')

# Screenshot
driver.save_screenshot('screenshot.png')

# Plot image
img = mpimg.imread('screenshot.png')
plt.figure(figsize=(8,8))
plt.axis('off')
imgplot = plt.imshow(img)

# Find element using tag names
text = driver.find_element(By.TAG_NAME, 'h3').text
print(text)

# Close driver
driver.close()

# %% [markdown]
# ## Pagination handling on https://www.minergie.ch

# %%
# Chrome-Driver
driver = webdriver.Chrome(service=service, options=options)

# Open file-connection
MyFile = open('minergie_objects.txt', 'w', encoding='utf-8')

obj = {}    

# Loop through first 5 pages and save objects to file
for i in range(5):
    
    # Generating URLs using page numbers
    url = str('https://www.minergie.ch/de/gebaeude/gebaeudeliste/?canton=&country=&zip_place=&street_nr=&gid=&participator=&typeofuse=&constructiontype=&year=&sortby=date_asc&numres=12&p=' + str(i+1))
    time.sleep(1)
    driver.get(url)
    
    # Click 'I agree' button for cookie-management on first page
    if i == 1:
        driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[3]/div[1]/button[3]').click()
    else:
        pass
    
    print(str('--------- Page:' + str(i+1) + '-------------------------------'))
    
    for n in range(12):
        
        path = str('/html/body/div[1]/div[4]/div[7]/div/div[' + str(n+1) + ']')

        obj['Object'] = driver.find_element(By.XPATH, path).text
        obj['Object'] = obj['Object'].replace("\n", "")
        print(obj['Object'])
        
        # Write to file
        MyFile.write(obj['Object'] + "\n")
        
# Close file-connection
MyFile.close()

# Close driver
driver.close()
# Out:
# --------- Page:1-------------------------------
# MinergieProvisorischZürich 8053Erneuerung, MFHGebäude ZH-10730, ... (3)
# MinergieDefinitivEsslingen 8133Erneuerung, EFHGebäude ZH-10336
# Minergie-A-ECOProvisorischBolligen 3065Neubau, SchuleGebäude BE-059-A-ECO
# MinergieProvisorischLausanne 1010Neubau, MFHGebäude VD-4577
# MinergieProvisorischYverdon-les-Bains 1400Neubau, MFHGebäude VD-4576
# Minergie-AProvisorischOriglio 6945Erneuerung, EFHGebäude TI-197-A
# Minergie-P-ECODefinitivNyon 1260Neubau, Verkauf / MFH / LagerGebäude VD-170-P-ECO, ... (3)
# Minergie-ECODefinitivRegensdorf 8105Neubau, MFHGebäude ZH-334-ECO
# Minergie-ECODefinitivRegensdorf 8105Neubau, MFHGebäude ZH-335-ECO
# Minergie-ECODefinitivRegensdorf 8105Neubau, MFHGebäude ZH-336-ECO
# Minergie-ECODefinitivRegensdorf 8105Neubau, MFHGebäude ZH-337-ECO
# Minergie-ECODefinitivRegensdorf 8105Neubau, MFHGebäude ZH-338-ECO
# --------- Page:2-------------------------------
# MinergieProvisorischBasel 4058Erneuerung, Restaurant / Verwaltung / MFHGebäude BS-231
# Minergie-PDefinitivCourtételle 2852Neubau, EFHGebäude JU-188-P
# Minergie-PProvisorischMassongex 1869Neubau, MFHGebäude VS-243-P, ... (2)
# Minergie-PProvisorischMassongex 1869Neubau, MFHGebäude VS-242-P
# Minergie-PProvisorischMassongex 1869Neubau, MFHGebäude VS-241-P
# Minergie-PProvisorischMassongex 1869Neubau, MFHGebäude VS-240-P
# Minergie-PDefinitivDottikon 5605Neubau, MFHGebäude AG-524-P, ... (2)
# Minergie-PDefinitivHägglingen 5607Neubau, EFHGebäude AG-761-P
# Minergie-PDefinitivKlosters 7250Neubau, EFH / HallenbadGebäude GR-195-P
# MinergieDefinitivWeinfelden 8570Neubau, EFHGebäude TG-3279
# Minergie-AProvisorischDallenwil 6383Neubau, MFHGebäude NW-024-A
# MinergieProvisorischHergiswil 6052Neubau, MFHGebäude NW-402
# --------- Page:3-------------------------------
# Minergie-PDefinitivInterlaken 3800Neubau, Verwaltung / MFHGebäude BE-595-P
# Minergie-PDefinitivInterlaken 3800Neubau, Verkauf / MFHGebäude BE-594-P
# MinergieProvisorischKaisten 5082Neubau, EFHGebäude AG-6455, ... (3)
# MinergieProvisorischKaisten 5082Neubau, EFHGebäude AG-6452, ... (3)
# MinergieProvisorischKaisten 5082Neubau, MFHGebäude AG-6451
# MinergieProvisorischKaisten 5082Neubau, MFHGebäude AG-6450
# MinergieProvisorischKaisten 5082Neubau, MFHGebäude AG-6449
# MinergieProvisorischKaisten 5082Neubau, MFHGebäude AG-6448
# MinergieProvisorischKaisten 5082Neubau, MFHGebäude AG-6447
# MinergieProvisorischKaisten 5082Neubau, MFHGebäude AG-6446
# MinergieProvisorischKaisten 5082Neubau, MFHGebäude AG-6445
# Minergie-PProvisorischWettingen 5430Neubau, MFHGebäude AG-1071-P
# --------- Page:4-------------------------------
# Minergie-PProvisorischWettingen 5430Neubau, MFHGebäude AG-1070-P
# Minergie-PProvisorischWettingen 5430Neubau, MFHGebäude AG-1069-P
# Minergie-PProvisorischWettingen 5430Neubau, MFHGebäude AG-1068-P
# MinergieDefinitivAltendorf 8852Neubau, MFHGebäude SZ-1341
# Minergie-PProvisorischOberlunkhofen 8917Neubau, MFHGebäude AG-1067-P
# MinergieDefinitivAltendorf 8852Neubau, MFHGebäude SZ-1340
# Minergie-PDefinitivLausanne 1004Erneuerung, MFHGebäude VD-276-P, ... (3)
# Minergie-PProvisorischAgno 6982Neubau, MFHGebäude TI-321-P
# MinergieProvisorischKüssnacht 6403Neubau, MFHGebäude SZ-1502
# MinergieProvisorischLa Tour-de-Peilz 1814Neubau, MFHGebäude VD-4575
# Minergie-PDefinitivSalgesch 3970Neubau, Schule / SportbauGebäude VS-162-P
# MinergieDefinitivNaters 3904Neubau, EFHGebäude VS-2967
# --------- Page:5-------------------------------
# MinergieDefinitivBrig 3900Neubau, EFHGebäude VS-2837
# Minergie-PDefinitivMuri 5630Neubau, MFHGebäude AG-785-P
# Minergie-PDefinitivMuri 5630Neubau, MFHGebäude AG-784-P
# Minergie-ECODefinitivWinterthur 8400Erneuerung, VerwaltungGebäude ZH-331-ECO
# Minergie-P-ECODefinitivWinterthur 8400Neubau, Verwaltung / MFHGebäude ZH-312-P-ECO
# Minergie-P-ECOProvisorischZürich 8051Neubau, Schule / SportbauGebäude ZH-438-P-ECO
# MinergieProvisorischHeerbrugg 9435Neubau, VerwaltungGebäude SG-2445
# Minergie-PProvisorischAadorf 8355Neubau, MFHGebäude TG-588-P
# MinergieProvisorischCrans VD 1299Neubau, EFHGebäude VD-4574
# Minergie-PDefinitivEich 6205Neubau, EFHGebäude LU-075-P
# Minergie-PDefinitivEich 6205Neubau, MFHGebäude LU-073-P
# Minergie-PDefinitivEich 6205Neubau, MFHGebäude LU-072-P

# %% [markdown]
# ## OpenStreetMap search location example

# %%
# Chrome driver
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://www.openstreetmap.org/#map=9/46.7054/8.0283')
time.sleep(2)

# Submit address
element = driver.find_element(By.XPATH, '/html/body/div[3]/div[1]/div[1]/form[1]/div/div/input')
element.send_keys("Melchsee-Frutt")
element.send_keys(Keys.RETURN)
time.sleep(2)

# Click info boxes
try:
    # Click 1st info-box
    info = WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div[1]/div[9]/button'))) 
    info.click()

    # Click 2nd info-box
    info = WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[3]/div[1]/div[10]/button'))) 
    info.click()

except:
    pass

# Screenshot of map
driver.save_screenshot('screenshot.png')
img = mpimg.imread('screenshot.png')
plt.figure(figsize=(6,6))
plt.axis('off')
imgplot = plt.imshow(img)

# Close driver
driver.close()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
